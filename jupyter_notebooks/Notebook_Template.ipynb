# %% [markdown]
# # **Sales price study**

# %% [markdown]
# ## Objectives
#
# * Write your notebook objective here, for example, "Fetch data from Kaggle and save as raw data", or "engineer features for modelling"
#
# ## Inputs
#
# * Write here which data or information you need to run the notebook
#
# ## Outputs
#
# * Write here which files, code or artefacts you generate by the end of the notebook
#
# ## Additional Comments
#
# * In case you have any additional comments that don't fit in the previous bullets, please state them here.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\david\\kod\\project-5\\housing-prices\\jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\david\\kod\\project-5\\housing-prices'

# %% [markdown]
# # Load Data

# %%
import pandas as pd
df = (pd.read_csv("outputs/datasets/collection/house-prices.csv")
    )
print(df.shape)
df.head()
# Out:
# (1460, 24)
#    1stFlrSF  2ndFlrSF  BedroomAbvGr BsmtExposure  BsmtFinSF1 BsmtFinType1  \
# 0       856     854.0           3.0           No         706          GLQ
# 1      1262       0.0           3.0           Gd         978          ALQ
# 2       920     866.0           3.0           Mn         486          GLQ
# 3       961       NaN           NaN           No         216          ALQ
# 4      1145       NaN           4.0           Av         655          GLQ
#
#    BsmtUnfSF  EnclosedPorch  GarageArea GarageFinish  ...  LotFrontage  \
# 0        150            0.0         548          RFn  ...         65.0
# 1        284            NaN         460          RFn  ...         80.0
# 2        434            0.0         608          RFn  ...         68.0
# 3        540            NaN         642          Unf  ...         60.0
# 4        490            0.0         836          RFn  ...         84.0
#
#    MasVnrArea OpenPorchSF  OverallCond  OverallQual  TotalBsmtSF  WoodDeckSF  \
# 0       196.0          61            5            7          856         0.0
# 1         0.0           0            8            6         1262         NaN
# 2       162.0          42            5            7          920         NaN
# 3         0.0          35            5            7          756         NaN
# 4       350.0          84            5            8         1145         NaN
#
#    YearBuilt  YearRemodAdd  SalePrice
# 0       2003          2003     208500
# 1       1976          1976     181500
# 2       2001          2002     223500
# 3       1915          1970     140000
# 4       2000          2000     250000
#
# [5 rows x 24 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Data Exploration

# %%
from ydata_profiling import ProfileReport
pd_report = ProfileReport(df=df, minimal=True)
pd_report.to_notebook_iframe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from ydata_profiling import ProfileReport
#       2 pd_report = ProfileReport(df=df, minimal=True)
#       3 pd_report.to_notebook_iframe()
#
# File c:\Users\david\kod\project-5\housing-prices\venv\Lib\site-packages\ydata_profiling\__init__.py:14
#      10 warnings.simplefilter("ignore", category=NumbaDeprecationWarning)
#      12 import importlib.util  # isort:skip # noqa
# ---> 14 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      15 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      16 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File c:\Users\david\kod\project-5\housing-prices\venv\Lib\site-packages\ydata_profiling\compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File c:\Users\david\kod\project-5\housing-prices\venv\Lib\site-packages\ydata_profiling\profile_report.py:31
#      29 from ydata_profiling.model import BaseDescription
#      30 from ydata_profiling.model.alerts import AlertType
# ---> 31 from ydata_profiling.model.describe import describe as describe_df
#      32 from ydata_profiling.model.sample import Sample
#      33 from ydata_profiling.model.summarizer import (
#      34     BaseSummarizer,
#      35     PandasProfilingSummarizer,
#      36     format_summary,
#      37     redact_summary,
#      38 )
#
# File c:\Users\david\kod\project-5\housing-prices\venv\Lib\site-packages\ydata_profiling\model\describe.py:20
#      18 from ydata_profiling.model.duplicates import get_duplicates
#      19 from ydata_profiling.model.missing import get_missing_active, get_missing_diagram
# ---> 20 from ydata_profiling.model.pairwise import get_scatter_plot, get_scatter_tasks
#      21 from ydata_profiling.model.sample import get_custom_sample, get_sample
#      22 from ydata_profiling.model.summarizer import BaseSummarizer
#
# File c:\Users\david\kod\project-5\housing-prices\venv\Lib\site-packages\ydata_profiling\model\pairwise.py:6
#       3 import pandas as pd
#       5 from ydata_profiling.config import Settings
# ----> 6 from ydata_profiling.visualisation.plot import scatter_pairwise
#       9 def get_scatter_tasks(
#      10     config: Settings, continuous_variables: list
#      11 ) -> List[Tuple[Any, Any]]:
#      12     if not config.interactions.continuous:
#
# File c:\Users\david\kod\project-5\housing-prices\venv\Lib\site-packages\ydata_profiling\visualisation\plot.py:8
#       6 import numpy as np
#       7 import pandas as pd
# ----> 8 import seaborn as sns
#       9 from matplotlib import pyplot as plt
#      10 from matplotlib.collections import PolyCollection
#
# File c:\Users\david\kod\project-5\housing-prices\venv\Lib\site-packages\seaborn\__init__.py:9
#       7 from .categorical import *  # noqa: F401,F403
#       8 from .distributions import *  # noqa: F401,F403
# ----> 9 from .matrix import *  # noqa: F401,F403
#      10 from .miscplot import *  # noqa: F401,F403
#      11 from .axisgrid import *  # noqa: F401,F403
#
# File c:\Users\david\kod\project-5\housing-prices\venv\Lib\site-packages\seaborn\matrix.py:13
#      10 import pandas as pd
#      11 from scipy.cluster import hierarchy
# ---> 13 from . import cm
#      14 from .axisgrid import Grid
#      15 from .utils import (despine, axis_ticklabels_overlap, relative_luminance,
#      16                     to_utf8)
#
# File c:\Users\david\kod\project-5\housing-prices\venv\Lib\site-packages\seaborn\cm.py:1582
#    1579     _cmap_r = colors.ListedColormap(_lut[::-1], _name + "_r")
#    1580     locals()[_name + "_r"] = _cmap_r
# -> 1582     mpl_cm.register_cmap(_name, _cmap)
#    1583     mpl_cm.register_cmap(_name + "_r", _cmap_r)
#    1585 del colors, mpl_cm
#
# AttributeError: module 'matplotlib.cm' has no attribute 'register_cmap'

# %% [markdown]
# ---

# %% [markdown]
# NOTE

# %% [markdown]
# * You may add as many sections as you want, as long as they support your project workflow.
# * All notebook's cells should be run top-down (you can't create a dynamic wherein a given point you need to go back to a previous cell to execute some task, like go back to a previous cell and refresh a variable content)

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# * If you do not need to push files to Repo, you may replace this section with "Conclusions and Next Steps" and state your conclusions and next steps.

# %%
import os
try:
  # create here your folder
  # os.makedirs(name='')
except Exception as e:
  print(e)
